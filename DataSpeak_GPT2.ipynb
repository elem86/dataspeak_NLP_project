# %%
# !pip install git+https://github.com/huggingface/transformers
# !pip install torch datasets evaluate
# !pip install transformers[torch]
# Out:
# Collecting git+https://github.com/huggingface/transformers
#   Cloning https://github.com/huggingface/transformers to /tmp/pip-req-build-er43y1ge
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers /tmp/pip-req-build-er43y1ge
#   Resolved https://github.com/huggingface/transformers to commit 245da7ed38d9f0dbd428c48e2ec4111ae5be2680
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.34.0.dev0) (3.12.2)
# Collecting huggingface-hub<1.0,>=0.16.4 (from transformers==4.34.0.dev0)
#   Downloading huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 6.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.34.0.dev0) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.34.0.dev0) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.34.0.dev0) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.34.0.dev0) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers==4.34.0.dev0) (2.31.0)
# Collecting tokenizers<0.15,>=0.14 (from transformers==4.34.0.dev0)
#   Downloading tokenizers-0.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 74.4 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers==4.34.0.dev0)
#   Downloading safetensors-0.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 73.8 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.34.0.dev0) (4.66.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers==4.34.0.dev0) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers==4.34.0.dev0) (4.5.0)
# Collecting huggingface-hub<1.0,>=0.16.4 (from transformers==4.34.0.dev0)
#   Downloading huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 34.2 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.34.0.dev0) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.34.0.dev0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.34.0.dev0) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.34.0.dev0) (2023.7.22)
# Building wheels for collected packages: transformers
#   Building wheel for transformers (pyproject.toml) ... done
#   Created wheel for transformers: filename=transformers-4.34.0.dev0-py3-none-any.whl size=7745696 sha256=6a86864abd6a5bc4caedbe0a43e52fcffde9502dd7fc5df608411242343abd03
#   Stored in directory: /tmp/pip-ephem-wheel-cache-rsc8pyp2/wheels/c0/14/d6/6c9a5582d2ac191ec0a483be151a4495fe1eb2a6706ca49f1b
# Successfully built transformers
# Installing collected packages: safetensors, huggingface-hub, tokenizers, transformers
# Successfully installed huggingface-hub-0.16.4 safetensors-0.3.3 tokenizers-0.14.0 transformers-4.34.0.dev0
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.0.1+cu118)
# Collecting datasets
#   Downloading datasets-2.14.5-py3-none-any.whl (519 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.6/519.6 kB 8.8 MB/s eta 0:00:00
# Collecting evaluate
#   Downloading evaluate-0.4.0-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.4/81.4 kB 12.9 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (3.27.4.1)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (16.0.6)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.23.5)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (9.0.0)
# Collecting dill<0.3.8,>=0.3.0 (from datasets)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 17.6 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.1)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 27.1 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 19.9 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<2023.9.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.8.5)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.16.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Collecting responses<0.19 (from evaluate)
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (3.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.3.post1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Installing collected packages: xxhash, dill, responses, multiprocess, datasets, evaluate
# Successfully installed datasets-2.14.5 dill-0.3.7 evaluate-0.4.0 multiprocess-0.70.15 responses-0.18.0 xxhash-3.3.0
# Requirement already satisfied: transformers[torch] in /usr/local/lib/python3.10/dist-packages (4.34.0.dev0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.16.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2.31.0)
# Requirement already satisfied: tokenizers<0.15,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.14.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.3.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (4.66.1)
# Requirement already satisfied: torch!=1.12.0,>=1.10 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2.0.1+cu118)
# Collecting accelerate>=0.20.3 (from transformers[torch])
#   Downloading accelerate-0.23.0-py3-none-any.whl (258 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.1/258.1 kB 6.9 MB/s eta 0:00:00
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.20.3->transformers[torch]) (5.9.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers[torch]) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers[torch]) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.10->transformers[torch]) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.10->transformers[torch]) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.10->transformers[torch]) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.10->transformers[torch]) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch!=1.12.0,>=1.10->transformers[torch]) (3.27.4.1)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch!=1.12.0,>=1.10->transformers[torch]) (16.0.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch!=1.12.0,>=1.10->transformers[torch]) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch!=1.12.0,>=1.10->transformers[torch]) (1.3.0)
# Installing collected packages: accelerate
# Successfully installed accelerate-0.23.0

# %%
# Importing necessary libraries and modules
import logging
import math
import os
import sys
import warnings
from dataclasses import dataclass, field
from itertools import chain
from typing import Optional

import datasets
import evaluate
import torch
from datasets import load_dataset

import transformers
from transformers import (
    CONFIG_MAPPING,
    MODEL_FOR_CAUSAL_LM_MAPPING,
    AutoConfig,
    AutoModelForCausalLM,
    AutoTokenizer,
    HfArgumentParser,
    Trainer,
    TrainingArguments,
    default_data_collator,
    is_torch_tpu_available,
    set_seed,
)
from transformers.testing_utils import CaptureLogger
from transformers.trainer_utils import get_last_checkpoint
from transformers.utils import check_min_version, send_example_telemetry
from transformers.utils.versions import require_version
from google.colab import drive


# Mount Google Drive
drive.mount('/content/drive')

# Navigate to the directory containing your data if it's in your drive
os.chdir('/content/drive/My Drive/DS')
# Out:
# Mounted at /content/drive

# %%
# # Create a smaller dataset with 10% of the original data
# with open('preprocessed_data.txt', 'r') as file:
#     lines = file.readlines()

# # Use 10% of the data
# small_data = lines[:len(lines)//3]

# with open('small_preprocessed_data.txt', 'w') as file:
#     file.writelines(small_data)

# %%
# Will error if the minimal version of Transformers is not installed. Remove at your own risks.
check_min_version("4.34.0.dev0")

require_version(
    "datasets>=1.8.0",
    "To fix: pip install -r examples/pytorch/language-modeling/requirements.txt",
)

logger = logging.getLogger(__name__)


MODEL_CONFIG_CLASSES = list(MODEL_FOR_CAUSAL_LM_MAPPING.keys())
MODEL_TYPES = tuple(conf.model_type for conf in MODEL_CONFIG_CLASSES)


@dataclass
class ModelArguments:
    """
    Arguments pertaining to which model/config/tokenizer we are going to fine-tune, or train from scratch.
    """

    model_name_or_path: Optional[str] = field(
        default='model_tuned3',
        metadata={
            "help": (
                "The model checkpoint for weights initialization. Don't set if you want to train a model from scratch."
            )
        },
    )
    model_type: Optional[str] = field(
        default=None,
        metadata={
            "help": "If training from scratch, pass a model type from the list: "
            + ", ".join(MODEL_TYPES)
        },
    )
    config_overrides: Optional[str] = field(
        default=None,
        metadata={
            "help": (
                "Override some existing default config settings when a model is trained from scratch. Example: "
                "n_embd=10,resid_pdrop=0.2,scale_attn_weights=false,summary_type=cls_index"
            )
        },
    )
    config_name: Optional[str] = field(
        default='model_tuned3',
        metadata={
            "help": "Pretrained config name or path if not the same as model_name"
        },
    )
    tokenizer_name: Optional[str] = field(
        default='model_tuned3',
        metadata={
            "help": "Pretrained tokenizer name or path if not the same as model_name"
        },
    )
    cache_dir: Optional[str] = field(
        default=None,
        metadata={
            "help": "Where do you want to store the pretrained models downloaded from huggingface.co"
        },
    )
    use_fast_tokenizer: bool = field(
        default=True,
        metadata={
            "help": "Whether to use one of the fast tokenizer (backed by the tokenizers library) or not."
        },
    )
    model_revision: str = field(
        default="main",
        metadata={
            "help": "The specific model version to use (can be a branch name, tag name or commit id)."
        },
    )
    token: str = field(
        default=None,
        metadata={
            "help": (
                "The token to use as HTTP bearer authorization for remote files. If not specified, will use the token "
                "generated when running `huggingface-cli login` (stored in `~/.huggingface`)."
            )
        },
    )
    use_auth_token: bool = field(
        default=None,
        metadata={
            "help": "The `use_auth_token` argument is deprecated and will be removed in v4.34. Please use `token`."
        },
    )
    trust_remote_code: bool = field(
        default=False,
        metadata={
            "help": (
                "Whether or not to allow for custom models defined on the Hub in their own modeling files. This option"
                "should only be set to `True` for repositories you trust and in which you have read the code, as it will"
                "execute code present on the Hub on your local machine."
            )
        },
    )
    torch_dtype: Optional[str] = field(
        default=None,
        metadata={
            "help": (
                "Override the default `torch.dtype` and load the model under this dtype. If `auto` is passed, the "
                "dtype will be automatically derived from the model's weights."
            ),
            "choices": ["auto", "bfloat16", "float16", "float32"],
        },
    )
    low_cpu_mem_usage: bool = field(
        default=False,
        metadata={
            "help": (
                "It is an option to create the model as an empty shell, then only materialize its parameters when the pretrained weights are loaded."
                "set True will benefit LLM loading time and RAM consumption."
            )
        },
    )

    def __post_init__(self):
        if self.config_overrides is not None and (
            self.config_name is not None or self.model_name_or_path is not None
        ):
            raise ValueError(
                "--config_overrides can't be used in combination with --config_name or --model_name_or_path"
            )


@dataclass
class DataTrainingArguments:
    """
    Arguments pertaining to what data we are going to input our model for training and eval.
    """

    dataset_name: Optional[str] = field(
        default=None,
        metadata={"help": "The name of the dataset to use (via the datasets library)."},
    )
    dataset_config_name: Optional[str] = field(
        default=None,
        metadata={
            "help": "The configuration name of the dataset to use (via the datasets library)."
        },
    )
    train_file: Optional[str] = field(
        default=None, metadata={"help": "The input training data file (a text file)."}
    )
    validation_file: Optional[str] = field(
        default=None,
        metadata={
            "help": "An optional input evaluation data file to evaluate the perplexity on (a text file)."
        },
    )
    max_train_samples: Optional[int] = field(
        default=None,
        metadata={
            "help": (
                "For debugging purposes or quicker training, truncate the number of training examples to this "
                "value if set."
            )
        },
    )
    max_eval_samples: Optional[int] = field(
        default=None,
        metadata={
            "help": (
                "For debugging purposes or quicker training, truncate the number of evaluation examples to this "
                "value if set."
            )
        },
    )
    streaming: bool = field(default=False, metadata={"help": "Enable streaming mode"})
    block_size: Optional[int] = field(
        default=None,
        metadata={
            "help": (
                "Optional input sequence length after tokenization. "
                "The training dataset will be truncated in block of this size for training. "
                "Default to the model max input length for single sentence inputs (take into account special tokens)."
            )
        },
    )
    overwrite_cache: bool = field(
        default=False,
        metadata={"help": "Overwrite the cached training and evaluation sets"},
    )
    validation_split_percentage: Optional[int] = field(
        default=5,
        metadata={
            "help": "The percentage of the train set used as validation set in case there's no validation split"
        },
    )
    preprocessing_num_workers: Optional[int] = field(
        default=None,
        metadata={"help": "The number of processes to use for the preprocessing."},
    )
    keep_linebreaks: bool = field(
        default=True,
        metadata={"help": "Whether to keep line breaks when using TXT files or not."},
    )

    def __post_init__(self):
        if self.streaming:
            require_version(
                "datasets>=2.0.0", "The streaming feature requires `datasets>=2.0.0`"
            )

        if (
            self.dataset_name is None
            and self.train_file is None
            and self.validation_file is None
        ):
            raise ValueError(
                "Need either a dataset name or a training/validation file."
            )
        else:
            if self.train_file is not None:
                extension = self.train_file.split(".")[-1]
                assert extension in [
                    "csv",
                    "json",
                    "txt",
                ], "`train_file` should be a csv, a json or a txt file."
            if self.validation_file is not None:
                extension = self.validation_file.split(".")[-1]
                assert extension in [
                    "csv",
                    "json",
                    "txt",
                ], "`validation_file` should be a csv, a json or a txt file."


def main():
    # See all possible arguments in src/transformers/training_args.py
    # or by passing the --help flag to this script.
    # We now keep distinct sets of args, for a cleaner separation of concerns.

    # parser = HfArgumentParser(
    #     (ModelArguments, DataTrainingArguments, TrainingArguments)
    # )
    # if len(sys.argv) == 2 and sys.argv[1].endswith(".json"):
    #     # If we pass only one argument to the script and it's the path to a json file,
    #     # let's parse it to get our arguments.
    #     model_args, data_args, training_args = parser.parse_json_file(
    #         json_file=os.path.abspath(sys.argv[1])
    #     )
    # else:
    #     model_args, data_args, training_args = parser.parse_args_into_dataclasses()

    # if model_args.use_auth_token is not None:
    #     warnings.warn(
    #         "The `use_auth_token` argument is deprecated and will be removed in v4.34.",
    #         FutureWarning,
    #     )
    #     if model_args.token is not None:
    #         raise ValueError(
    #             "`token` and `use_auth_token` are both specified. Please set only the argument `token`."
    #         )
    #     model_args.token = model_args.use_auth_token

        # Manually assign the arguments
    model_args = ModelArguments(
        model_name_or_path='model_tuned3',  # or the path to your model
        # ... any other ModelArguments you want to set ...
    )

    data_args = DataTrainingArguments(
        train_file='small_preprocessed_data.txt',  # replace with the path to your training file
        # ... any other DataTrainingArguments you want to set ...
    )

    training_args = TrainingArguments(
        output_dir='model_tuned4',  # replace with the path to your output directory
        do_train=True,
        do_eval=True,
        per_device_train_batch_size=12,
        save_total_limit=2,
        num_train_epochs=3,
        fp16=True,  # Enable mixed-precision training
        dataloader_num_workers=120,
        gradient_accumulation_steps=2,
        learning_rate=0.00001,
        # resume_from_checkpoint= 'model_tuned2/checkpoint-47000',
        # ... any other TrainingArguments you want to set ...
    )

    # The rest of the code remains unchanged
    if model_args.use_auth_token is not None:
        warnings.warn(
            "The `use_auth_token` argument is deprecated and will be removed in v4.34.",
            FutureWarning,
        )
        if model_args.token is not None:
            raise ValueError(
                "`token` and `use_auth_token` are both specified. Please set only the argument `token`."
            )
        model_args.token = model_args.use_auth_token

    # Sending telemetry. Tracking the example usage helps us better allocate resources to maintain them. The
    # information sent is the one passed as arguments along with your Python/PyTorch versions.
    send_example_telemetry("run_clm", model_args, data_args)

    # Setup logging
    logging.basicConfig(
        format="%(asctime)s - %(levelname)s - %(name)s - %(message)s",
        datefmt="%m/%d/%Y %H:%M:%S",
        handlers=[logging.StreamHandler(sys.stdout)],
    )

    if training_args.should_log:
        # The default of training_args.log_level is passive, so we set log level at info here to have that default.
        transformers.utils.logging.set_verbosity_info()

    log_level = training_args.get_process_log_level()
    logger.setLevel(log_level)
    datasets.utils.logging.set_verbosity(log_level)
    transformers.utils.logging.set_verbosity(log_level)
    transformers.utils.logging.enable_default_handler()
    transformers.utils.logging.enable_explicit_format()

    # Log on each process the small summary:
    logger.warning(
        f"Process rank: {training_args.local_rank}, device: {training_args.device}, n_gpu: {training_args.n_gpu}"
        + f"distributed training: {training_args.parallel_mode.value == 'distributed'}, 16-bits training: {training_args.fp16}"
    )
    logger.info(f"Training/evaluation parameters {training_args}")

    # Detecting last checkpoint.
    last_checkpoint = None
    if (
        os.path.isdir(training_args.output_dir)
        and training_args.do_train
        and not training_args.overwrite_output_dir
    ):
        last_checkpoint = get_last_checkpoint(training_args.output_dir)
        if last_checkpoint is None and len(os.listdir(training_args.output_dir)) > 0:
            raise ValueError(
                f"Output directory ({training_args.output_dir}) already exists and is not empty. "
                "Use --overwrite_output_dir to overcome."
            )
        elif (
            last_checkpoint is not None and training_args.resume_from_checkpoint is None
        ):
            logger.info(
                f"Checkpoint detected, resuming training at {last_checkpoint}. To avoid this behavior, change "
                "the `--output_dir` or add `--overwrite_output_dir` to train from scratch."
            )

    # Set seed before initializing model.
    set_seed(training_args.seed)

    # Get the datasets: you can either provide your own CSV/JSON/TXT training and evaluation files (see below)
    # or just provide the name of one of the public datasets available on the hub at https://huggingface.co/datasets/
    # (the dataset will be downloaded automatically from the datasets Hub).
    #
    # For CSV/JSON files, this script will use the column called 'text' or the first column if no column called
    # 'text' is found. You can easily tweak this behavior (see below).
    #
    # In distributed training, the load_dataset function guarantee that only one local process can concurrently
    # download the dataset.
    if data_args.dataset_name is not None:
        # Downloading and loading a dataset from the hub.
        raw_datasets = load_dataset(
            data_args.dataset_name,
            data_args.dataset_config_name,
            cache_dir=model_args.cache_dir,
            token=model_args.token,
            streaming=data_args.streaming,
        )
        if "validation" not in raw_datasets.keys():
            raw_datasets["validation"] = load_dataset(
                data_args.dataset_name,
                data_args.dataset_config_name,
                split=f"train[:{data_args.validation_split_percentage}%]",
                cache_dir=model_args.cache_dir,
                token=model_args.token,
                streaming=data_args.streaming,
            )
            raw_datasets["train"] = load_dataset(
                data_args.dataset_name,
                data_args.dataset_config_name,
                split=f"train[{data_args.validation_split_percentage}%:]",
                cache_dir=model_args.cache_dir,
                token=model_args.token,
                streaming=data_args.streaming,
            )
    else:
        data_files = {}
        dataset_args = {}
        if data_args.train_file is not None:
            data_files["train"] = data_args.train_file
        if data_args.validation_file is not None:
            data_files["validation"] = data_args.validation_file
        extension = (
            data_args.train_file.split(".")[-1]
            if data_args.train_file is not None
            else data_args.validation_file.split(".")[-1]
        )
        if extension == "txt":
            extension = "text"
            dataset_args["keep_linebreaks"] = data_args.keep_linebreaks
        raw_datasets = load_dataset(
            extension,
            data_files=data_files,
            cache_dir=model_args.cache_dir,
            token=model_args.token,
            **dataset_args,
        )
        # If no validation data is there, validation_split_percentage will be used to divide the dataset.
        if "validation" not in raw_datasets.keys():
            raw_datasets["validation"] = load_dataset(
                extension,
                data_files=data_files,
                split=f"train[:{data_args.validation_split_percentage}%]",
                cache_dir=model_args.cache_dir,
                token=model_args.token,
                **dataset_args,
            )
            raw_datasets["train"] = load_dataset(
                extension,
                data_files=data_files,
                split=f"train[{data_args.validation_split_percentage}%:]",
                cache_dir=model_args.cache_dir,
                token=model_args.token,
                **dataset_args,
            )

    # See more about loading any type of standard or custom dataset (from files, python dict, pandas DataFrame, etc) at
    # https://huggingface.co/docs/datasets/loading_datasets.html.

    # Load pretrained model and tokenizer
    #
    # Distributed training:
    # The .from_pretrained methods guarantee that only one local process can concurrently
    # download model & vocab.

    config_kwargs = {
        "cache_dir": model_args.cache_dir,
        "revision": model_args.model_revision,
        "token": model_args.token,
        "trust_remote_code": model_args.trust_remote_code,
    }
    if model_args.config_name:
        config = AutoConfig.from_pretrained(model_args.config_name, **config_kwargs)
    elif model_args.model_name_or_path:
        config = AutoConfig.from_pretrained(
            model_args.model_name_or_path, **config_kwargs
        )
    else:
        config = CONFIG_MAPPING[model_args.model_type]()
        logger.warning("You are instantiating a new config instance from scratch.")
        if model_args.config_overrides is not None:
            logger.info(f"Overriding config: {model_args.config_overrides}")
            config.update_from_string(model_args.config_overrides)
            logger.info(f"New config: {config}")

    tokenizer_kwargs = {
        "cache_dir": model_args.cache_dir,
        "use_fast": model_args.use_fast_tokenizer,
        "revision": model_args.model_revision,
        "token": model_args.token,
        "trust_remote_code": model_args.trust_remote_code,
    }
    if model_args.tokenizer_name:
        tokenizer = AutoTokenizer.from_pretrained(
            model_args.tokenizer_name, **tokenizer_kwargs
        )
    elif model_args.model_name_or_path:
        tokenizer = AutoTokenizer.from_pretrained(
            model_args.model_name_or_path, **tokenizer_kwargs
        )
    else:
        raise ValueError(
            "You are instantiating a new tokenizer from scratch. This is not supported by this script."
            "You can do it from another script, save it, and load it from here, using --tokenizer_name."
        )

    if model_args.model_name_or_path:
        torch_dtype = (
            model_args.torch_dtype
            if model_args.torch_dtype in ["auto", None]
            else getattr(torch, model_args.torch_dtype)
        )
        model = AutoModelForCausalLM.from_pretrained(
            model_args.model_name_or_path,
            from_tf=bool(".ckpt" in model_args.model_name_or_path),
            config=config,
            cache_dir=model_args.cache_dir,
            revision=model_args.model_revision,
            token=model_args.token,
            trust_remote_code=model_args.trust_remote_code,
            torch_dtype=torch_dtype,
            low_cpu_mem_usage=model_args.low_cpu_mem_usage,
        )
    else:
        model = AutoModelForCausalLM.from_config(
            config, trust_remote_code=model_args.trust_remote_code
        )
        n_params = sum({p.data_ptr(): p.numel() for p in model.parameters()}.values())
        logger.info(
            f"Training new model from scratch - Total size={n_params/2**20:.2f}M params"
        )

    # We resize the embeddings only when necessary to avoid index errors. If you are creating a model from scratch
    # on a small vocab and want a smaller embedding size, remove this test.
    embedding_size = model.get_input_embeddings().weight.shape[0]
    if len(tokenizer) > embedding_size:
        model.resize_token_embeddings(len(tokenizer))

    # Preprocessing the datasets.
    # First we tokenize all the texts.
    if training_args.do_train:
        column_names = list(raw_datasets["train"].features)
    else:
        column_names = list(raw_datasets["validation"].features)
    text_column_name = "text" if "text" in column_names else column_names[0]

    # since this will be pickled to avoid _LazyModule error in Hasher force logger loading before tokenize_function
    tok_logger = transformers.utils.logging.get_logger(
        "transformers.tokenization_utils_base"
    )

    def tokenize_function(examples):
        with CaptureLogger(tok_logger) as cl:
            output = tokenizer(examples[text_column_name])
        # clm input could be much much longer than block_size
        if "Token indices sequence length is longer than the" in cl.out:
            tok_logger.warning(
                "^^^^^^^^^^^^^^^^ Please ignore the warning above - this long input will be chunked into smaller bits"
                " before being passed to the model."
            )
        return output

    with training_args.main_process_first(desc="dataset map tokenization"):
        if not data_args.streaming:
            tokenized_datasets = raw_datasets.map(
                tokenize_function,
                batched=True,
                num_proc=data_args.preprocessing_num_workers,
                remove_columns=column_names,
                load_from_cache_file=not data_args.overwrite_cache,
                desc="Running tokenizer on dataset",
            )
        else:
            tokenized_datasets = raw_datasets.map(
                tokenize_function,
                batched=True,
                remove_columns=column_names,
            )

    if data_args.block_size is None:
        block_size = tokenizer.model_max_length
        if block_size > 1024:
            logger.warning(
                "The chosen tokenizer supports a `model_max_length` that is longer than the default `block_size` value"
                " of 1024. If you would like to use a longer `block_size` up to `tokenizer.model_max_length` you can"
                " override this default with `--block_size xxx`."
            )
            block_size = 1024
    else:
        if data_args.block_size > tokenizer.model_max_length:
            logger.warning(
                f"The block_size passed ({data_args.block_size}) is larger than the maximum length for the model"
                f"({tokenizer.model_max_length}). Using block_size={tokenizer.model_max_length}."
            )
        block_size = min(data_args.block_size, tokenizer.model_max_length)

    # Main data processing function that will concatenate all texts from our dataset and generate chunks of block_size.
    def group_texts(examples):
        # Concatenate all texts.
        concatenated_examples = {k: list(chain(*examples[k])) for k in examples.keys()}
        total_length = len(concatenated_examples[list(examples.keys())[0]])
        # We drop the small remainder, and if the total_length < block_size  we exclude this batch and return an empty dict.
        # We could add padding if the model supported it instead of this drop, you can customize this part to your needs.
        total_length = (total_length // block_size) * block_size
        # Split by chunks of max_len.
        result = {
            k: [t[i : i + block_size] for i in range(0, total_length, block_size)]
            for k, t in concatenated_examples.items()
        }
        result["labels"] = result["input_ids"].copy()
        return result

    # Note that with `batched=True`, this map processes 1,000 texts together, so group_texts throws away a remainder
    # for each of those groups of 1,000 texts. You can adjust that batch_size here but a higher value might be slower
    # to preprocess.
    #
    # To speed up this part, we use multiprocessing. See the documentation of the map method for more information:
    # https://huggingface.co/docs/datasets/process#map

    with training_args.main_process_first(desc="grouping texts together"):
        if not data_args.streaming:
            lm_datasets = tokenized_datasets.map(
                group_texts,
                batched=True,
                num_proc=data_args.preprocessing_num_workers,
                load_from_cache_file=not data_args.overwrite_cache,
                desc=f"Grouping texts in chunks of {block_size}",
            )
        else:
            lm_datasets = tokenized_datasets.map(
                group_texts,
                batched=True,
            )

    if training_args.do_train:
        if "train" not in tokenized_datasets:
            raise ValueError("--do_train requires a train dataset")
        train_dataset = lm_datasets["train"]
        if data_args.max_train_samples is not None:
            max_train_samples = min(len(train_dataset), data_args.max_train_samples)
            train_dataset = train_dataset.select(range(max_train_samples))

    if training_args.do_eval:
        if "validation" not in tokenized_datasets:
            raise ValueError("--do_eval requires a validation dataset")
        eval_dataset = lm_datasets["validation"]
        if data_args.max_eval_samples is not None:
            max_eval_samples = min(len(eval_dataset), data_args.max_eval_samples)
            eval_dataset = eval_dataset.select(range(max_eval_samples))

        def preprocess_logits_for_metrics(logits, labels):
            if isinstance(logits, tuple):
                # Depending on the model and config, logits may contain extra tensors,
                # like past_key_values, but logits always come first
                logits = logits[0]
            return logits.argmax(dim=-1)

        metric = evaluate.load("accuracy")

        def compute_metrics(eval_preds):
            preds, labels = eval_preds
            # preds have the same shape as the labels, after the argmax(-1) has been calculated
            # by preprocess_logits_for_metrics but we need to shift the labels
            labels = labels[:, 1:].reshape(-1)
            preds = preds[:, :-1].reshape(-1)
            return metric.compute(predictions=preds, references=labels)

    # Initialize our Trainer
    trainer = Trainer(
        model=model,
        args=training_args,
        train_dataset=train_dataset if training_args.do_train else None,
        eval_dataset=eval_dataset if training_args.do_eval else None,
        tokenizer=tokenizer,
        # Data collator will default to DataCollatorWithPadding, so we change it.
        data_collator=default_data_collator,
        compute_metrics=compute_metrics
        if training_args.do_eval and not is_torch_tpu_available()
        else None,
        preprocess_logits_for_metrics=preprocess_logits_for_metrics
        if training_args.do_eval and not is_torch_tpu_available()
        else None,
    )

    # Training
    if training_args.do_train:
        checkpoint = None
        if training_args.resume_from_checkpoint is not None:
            checkpoint = training_args.resume_from_checkpoint
        elif last_checkpoint is not None:
            checkpoint = last_checkpoint
        train_result = trainer.train(resume_from_checkpoint=checkpoint)
        trainer.save_model()  # Saves the tokenizer too for easy upload

        metrics = train_result.metrics

        max_train_samples = (
            data_args.max_train_samples
            if data_args.max_train_samples is not None
            else len(train_dataset)
        )
        metrics["train_samples"] = min(max_train_samples, len(train_dataset))

        trainer.log_metrics("train", metrics)
        trainer.save_metrics("train", metrics)
        trainer.save_state()

    # Evaluation
    if training_args.do_eval:
        logger.info("*** Evaluate ***")

        metrics = trainer.evaluate()

        max_eval_samples = (
            data_args.max_eval_samples
            if data_args.max_eval_samples is not None
            else len(eval_dataset)
        )
        metrics["eval_samples"] = min(max_eval_samples, len(eval_dataset))
        try:
            perplexity = math.exp(metrics["eval_loss"])
        except OverflowError:
            perplexity = float("inf")
        metrics["perplexity"] = perplexity

        trainer.log_metrics("eval", metrics)
        trainer.save_metrics("eval", metrics)

    kwargs = {
        "finetuned_from": model_args.model_name_or_path,
        "tasks": "text-generation",
    }
    if data_args.dataset_name is not None:
        kwargs["dataset_tags"] = data_args.dataset_name
        if data_args.dataset_config_name is not None:
            kwargs["dataset_args"] = data_args.dataset_config_name
            kwargs[
                "dataset"
            ] = f"{data_args.dataset_name} {data_args.dataset_config_name}"
        else:
            kwargs["dataset"] = data_args.dataset_name

    if training_args.push_to_hub:
        trainer.push_to_hub(**kwargs)
    else:
        trainer.create_model_card(**kwargs)


def _mp_fn(index):
    # For xla_spawn (TPUs)
    main()


if __name__ == "__main__":

    main()
# Out:
# WARNING:__main__:Process rank: 0, device: cuda:0, n_gpu: 1distributed training: False, 16-bits training: True
# INFO:__main__:Training/evaluation parameters TrainingArguments(
# _n_gpu=1,
# adafactor=False,
# adam_beta1=0.9,
# adam_beta2=0.999,
# adam_epsilon=1e-08,
# auto_find_batch_size=False,
# bf16=False,
# bf16_full_eval=False,
# data_seed=None,
# dataloader_drop_last=False,
# dataloader_num_workers=120,
# dataloader_pin_memory=True,
# ddp_backend=None,
# ddp_broadcast_buffers=None,
# ddp_bucket_cap_mb=None,
# ddp_find_unused_parameters=None,
# ddp_timeout=1800,
# debug=[],
# deepspeed=None,
# disable_tqdm=False,
# dispatch_batches=None,
# do_eval=True,
# do_predict=False,
# do_train=True,
# eval_accumulation_steps=None,
# eval_delay=0,
# eval_steps=None,
# evaluation_strategy=no,
# fp16=True,
# fp16_backend=auto,
# fp16_full_eval=False,
# fp16_opt_level=O1,
# fsdp=[],
# fsdp_config={'min_num_params': 0, 'xla': False, 'xla_fsdp_grad_ckpt': False},
# fsdp_min_num_params=0,
# fsdp_transformer_layer_cls_to_wrap=None,
# full_determinism=False,
# gradient_accumulation_steps=2,
# gradient_checkpointing=False,
# greater_is_better=None,
# group_by_length=False,
# half_precision_backend=auto,
# hub_always_push=False,
# hub_model_id=None,
# hub_private_repo=False,
# hub_strategy=every_save,
# hub_token=<HUB_TOKEN>,
# ignore_data_skip=False,
# include_inputs_for_metrics=False,
# include_tokens_per_second=False,
# jit_mode_eval=False,
# label_names=None,
# label_smoothing_factor=0.0,
# learning_rate=1e-05,
# length_column_name=length,
# load_best_model_at_end=False,
# local_rank=0,
# log_level=passive,
# log_level_replica=warning,
# log_on_each_node=True,
# logging_dir=model_tuned4/runs/Oct03_10-19-42_edf3aa5c402b,
# logging_first_step=False,
# logging_nan_inf_filter=True,
# logging_steps=500,
# logging_strategy=steps,
# lr_scheduler_type=linear,
# max_grad_norm=1.0,
# max_steps=-1,
# metric_for_best_model=None,
# mp_parameters=,
# no_cuda=False,
# num_train_epochs=3,
# optim=adamw_torch,
# optim_args=None,
# output_dir=model_tuned4,
# overwrite_output_dir=False,
# past_index=-1,
# per_device_eval_batch_size=8,
# per_device_train_batch_size=12,
# prediction_loss_only=False,
# push_to_hub=False,
# push_to_hub_model_id=None,
# push_to_hub_organization=None,
# push_to_hub_token=<PUSH_TO_HUB_TOKEN>,
# ray_scope=last,
# remove_unused_columns=True,
# report_to=['tensorboard'],
# resume_from_checkpoint=None,
# run_name=model_tuned4,
# save_on_each_node=False,
# save_safetensors=False,
# save_steps=500,
# save_strategy=steps,
# save_total_limit=2,
# seed=42,
# sharded_ddp=[],
# skip_memory_metrics=True,
# tf32=None,
# torch_compile=False,
# torch_compile_backend=None,
# torch_compile_mode=None,
# torchdynamo=None,
# tpu_metrics_debug=False,
# tpu_num_cores=None,
# use_cpu=False,
# use_ipex=False,
# use_legacy_prediction_loop=False,
# use_mps_device=False,
# warmup_ratio=0.0,
# warmup_steps=0,
# weight_decay=0.0,
# )
# Using custom data configuration default-75b4633caf9bee37
# INFO:datasets.builder:Using custom data configuration default-75b4633caf9bee37
# Loading Dataset Infos from /usr/local/lib/python3.10/dist-packages/datasets/packaged_modules/text
# INFO:datasets.info:Loading Dataset Infos from /usr/local/lib/python3.10/dist-packages/datasets/packaged_modules/text
# Generating dataset text (/root/.cache/huggingface/datasets/text/default-75b4633caf9bee37/0.0.0/c4a140d10f020282918b5dd1b8a49f0104729c6177f60a6b49ec2a365ec69f34)
# INFO:datasets.builder:Generating dataset text (/root/.cache/huggingface/datasets/text/default-75b4633caf9bee37/0.0.0/c4a140d10f020282918b5dd1b8a49f0104729c6177f60a6b49ec2a365ec69f34)
# Downloading and preparing dataset text/default to /root/.cache/huggingface/datasets/text/default-75b4633caf9bee37/0.0.0/c4a140d10f020282918b5dd1b8a49f0104729c6177f60a6b49ec2a365ec69f34...
# INFO:datasets.builder:Downloading and preparing dataset text/default to /root/.cache/huggingface/datasets/text/default-75b4633caf9bee37/0.0.0/c4a140d10f020282918b5dd1b8a49f0104729c6177f60a6b49ec2a365ec69f34...
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading took 0.0 min
# INFO:datasets.download.download_manager:Downloading took 0.0 min
# Checksum Computation took 0.0 min
# INFO:datasets.download.download_manager:Checksum Computation took 0.0 min
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split
# INFO:datasets.builder:Generating train split
# Generating train split: 0 examples [00:00, ? examples/s]
# Unable to verify splits sizes.
# INFO:datasets.utils.info_utils:Unable to verify splits sizes.
# Dataset text downloaded and prepared to /root/.cache/huggingface/datasets/text/default-75b4633caf9bee37/0.0.0/c4a140d10f020282918b5dd1b8a49f0104729c6177f60a6b49ec2a365ec69f34. Subsequent calls will reuse this data.
# INFO:datasets.builder:Dataset text downloaded and prepared to /root/.cache/huggingface/datasets/text/default-75b4633caf9bee37/0.0.0/c4a140d10f020282918b5dd1b8a49f0104729c6177f60a6b49ec2a365ec69f34. Subsequent calls will reuse this data.
# Using custom data configuration default-75b4633caf9bee37
# INFO:datasets.builder:Using custom data configuration default-75b4633caf9bee37
# Loading Dataset Infos from /usr/local/lib/python3.10/dist-packages/datasets/packaged_modules/text
# INFO:datasets.info:Loading Dataset Infos from /usr/local/lib/python3.10/dist-packages/datasets/packaged_modules/text
# Overwrite dataset info from restored data version if exists.
# INFO:datasets.builder:Overwrite dataset info from restored data version if exists.
# Loading Dataset info from /root/.cache/huggingface/datasets/text/default-75b4633caf9bee37/0.0.0/c4a140d10f020282918b5dd1b8a49f0104729c6177f60a6b49ec2a365ec69f34
# INFO:datasets.info:Loading Dataset info from /root/.cache/huggingface/datasets/text/default-75b4633caf9bee37/0.0.0/c4a140d10f020282918b5dd1b8a49f0104729c6177f60a6b49ec2a365ec69f34
# Found cached dataset text (/root/.cache/huggingface/datasets/text/default-75b4633caf9bee37/0.0.0/c4a140d10f020282918b5dd1b8a49f0104729c6177f60a6b49ec2a365ec69f34)
# INFO:datasets.builder:Found cached dataset text (/root/.cache/huggingface/datasets/text/default-75b4633caf9bee37/0.0.0/c4a140d10f020282918b5dd1b8a49f0104729c6177f60a6b49ec2a365ec69f34)
# Loading Dataset info from /root/.cache/huggingface/datasets/text/default-75b4633caf9bee37/0.0.0/c4a140d10f020282918b5dd1b8a49f0104729c6177f60a6b49ec2a365ec69f34
# INFO:datasets.info:Loading Dataset info from /root/.cache/huggingface/datasets/text/default-75b4633caf9bee37/0.0.0/c4a140d10f020282918b5dd1b8a49f0104729c6177f60a6b49ec2a365ec69f34
# Using custom data configuration default-75b4633caf9bee37
# INFO:datasets.builder:Using custom data configuration default-75b4633caf9bee37
# Loading Dataset Infos from /usr/local/lib/python3.10/dist-packages/datasets/packaged_modules/text
# INFO:datasets.info:Loading Dataset Infos from /usr/local/lib/python3.10/dist-packages/datasets/packaged_modules/text
# Overwrite dataset info from restored data version if exists.
# INFO:datasets.builder:Overwrite dataset info from restored data version if exists.
# Loading Dataset info from /root/.cache/huggingface/datasets/text/default-75b4633caf9bee37/0.0.0/c4a140d10f020282918b5dd1b8a49f0104729c6177f60a6b49ec2a365ec69f34
# INFO:datasets.info:Loading Dataset info from /root/.cache/huggingface/datasets/text/default-75b4633caf9bee37/0.0.0/c4a140d10f020282918b5dd1b8a49f0104729c6177f60a6b49ec2a365ec69f34
# Found cached dataset text (/root/.cache/huggingface/datasets/text/default-75b4633caf9bee37/0.0.0/c4a140d10f020282918b5dd1b8a49f0104729c6177f60a6b49ec2a365ec69f34)
# INFO:datasets.builder:Found cached dataset text (/root/.cache/huggingface/datasets/text/default-75b4633caf9bee37/0.0.0/c4a140d10f020282918b5dd1b8a49f0104729c6177f60a6b49ec2a365ec69f34)
# Loading Dataset info from /root/.cache/huggingface/datasets/text/default-75b4633caf9bee37/0.0.0/c4a140d10f020282918b5dd1b8a49f0104729c6177f60a6b49ec2a365ec69f34
# INFO:datasets.info:Loading Dataset info from /root/.cache/huggingface/datasets/text/default-75b4633caf9bee37/0.0.0/c4a140d10f020282918b5dd1b8a49f0104729c6177f60a6b49ec2a365ec69f34
# [INFO|configuration_utils.py:713] 2023-10-03 10:20:02,799 >> loading configuration file model_tuned3/config.json
# [INFO|configuration_utils.py:775] 2023-10-03 10:20:02,801 >> Model config GPT2Config {
#   "_name_or_path": "model_tuned3",
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "torch_dtype": "float32",
#   "transformers_version": "4.34.0.dev0",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# [INFO|tokenization_utils_base.py:2038] 2023-10-03 10:20:03,464 >> loading file vocab.json
# [INFO|tokenization_utils_base.py:2038] 2023-10-03 10:20:03,465 >> loading file merges.txt
# [INFO|tokenization_utils_base.py:2038] 2023-10-03 10:20:03,466 >> loading file tokenizer.json
# [INFO|tokenization_utils_base.py:2038] 2023-10-03 10:20:03,467 >> loading file added_tokens.json
# [INFO|tokenization_utils_base.py:2038] 2023-10-03 10:20:03,468 >> loading file special_tokens_map.json
# [INFO|tokenization_utils_base.py:2038] 2023-10-03 10:20:03,469 >> loading file tokenizer_config.json
# [WARNING|logging.py:290] 2023-10-03 10:20:04,220 >> Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# [INFO|modeling_utils.py:2986] 2023-10-03 10:20:04,228 >> loading weights file model_tuned3/pytorch_model.bin
# [INFO|configuration_utils.py:770] 2023-10-03 10:20:10,205 >> Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256
# }
#
# [INFO|modeling_utils.py:3771] 2023-10-03 10:20:11,622 >> All model checkpoint weights were used when initializing GPT2LMHeadModel.
#
# [INFO|modeling_utils.py:3779] 2023-10-03 10:20:11,624 >> All the weights of GPT2LMHeadModel were initialized from the model checkpoint at model_tuned3.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use GPT2LMHeadModel for predictions without further training.
# [INFO|configuration_utils.py:728] 2023-10-03 10:20:12,456 >> loading configuration file model_tuned3/generation_config.json
# [INFO|configuration_utils.py:770] 2023-10-03 10:20:12,457 >> Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256
# }
# Running tokenizer on dataset:   0%|          | 0/812619 [00:00<?, ? examples/s]
# [WARNING|tokenization_utils_base.py:3833] 2023-10-03 10:20:12,565 >> Token indices sequence length is longer than the specified maximum sequence length for this model (1650 > 1024). Running this sequence through the model will result in indexing errors
# [WARNING|<ipython-input-4-35ee391bbc68>:529] 2023-10-03 10:20:12,567 >> ^^^^^^^^^^^^^^^^ Please ignore the warning above - this long input will be chunked into smaller bits before being passed to the model.
# Caching processed dataset at /root/.cache/huggingface/datasets/text/default-75b4633caf9bee37/0.0.0/c4a140d10f020282918b5dd1b8a49f0104729c6177f60a6b49ec2a365ec69f34/cache-d06ba3bb7e90fbbc.arrow
# INFO:datasets.arrow_dataset:Caching processed dataset at /root/.cache/huggingface/datasets/text/default-75b4633caf9bee37/0.0.0/c4a140d10f020282918b5dd1b8a49f0104729c6177f60a6b49ec2a365ec69f34/cache-d06ba3bb7e90fbbc.arrow
# Running tokenizer on dataset:   0%|          | 0/42769 [00:00<?, ? examples/s]
# Caching processed dataset at /root/.cache/huggingface/datasets/text/default-75b4633caf9bee37/0.0.0/c4a140d10f020282918b5dd1b8a49f0104729c6177f60a6b49ec2a365ec69f34/cache-ce9404184cd91a79.arrow
# INFO:datasets.arrow_dataset:Caching processed dataset at /root/.cache/huggingface/datasets/text/default-75b4633caf9bee37/0.0.0/c4a140d10f020282918b5dd1b8a49f0104729c6177f60a6b49ec2a365ec69f34/cache-ce9404184cd91a79.arrow
# Grouping texts in chunks of 1024:   0%|          | 0/812619 [00:00<?, ? examples/s]
# Caching processed dataset at /root/.cache/huggingface/datasets/text/default-75b4633caf9bee37/0.0.0/c4a140d10f020282918b5dd1b8a49f0104729c6177f60a6b49ec2a365ec69f34/cache-628f293287f93e44.arrow
# INFO:datasets.arrow_dataset:Caching processed dataset at /root/.cache/huggingface/datasets/text/default-75b4633caf9bee37/0.0.0/c4a140d10f020282918b5dd1b8a49f0104729c6177f60a6b49ec2a365ec69f34/cache-628f293287f93e44.arrow
# Grouping texts in chunks of 1024:   0%|          | 0/42769 [00:00<?, ? examples/s]
# Caching processed dataset at /root/.cache/huggingface/datasets/text/default-75b4633caf9bee37/0.0.0/c4a140d10f020282918b5dd1b8a49f0104729c6177f60a6b49ec2a365ec69f34/cache-3fa335f87ae493d4.arrow
# INFO:datasets.arrow_dataset:Caching processed dataset at /root/.cache/huggingface/datasets/text/default-75b4633caf9bee37/0.0.0/c4a140d10f020282918b5dd1b8a49f0104729c6177f60a6b49ec2a365ec69f34/cache-3fa335f87ae493d4.arrow
# Downloading builder script:   0%|          | 0.00/4.20k [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 120 worker processes in total. Our suggested max number of worker in current system is 12, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# [INFO|trainer.py:1760] 2023-10-03 10:23:40,418 >> ***** Running training *****
# [INFO|trainer.py:1761] 2023-10-03 10:23:40,419 >>   Num examples = 105,254
# [INFO|trainer.py:1762] 2023-10-03 10:23:40,419 >>   Num Epochs = 3
# [INFO|trainer.py:1763] 2023-10-03 10:23:40,420 >>   Instantaneous batch size per device = 12
# [INFO|trainer.py:1766] 2023-10-03 10:23:40,421 >>   Total train batch size (w. parallel, distributed & accumulation) = 24
# [INFO|trainer.py:1767] 2023-10-03 10:23:40,422 >>   Gradient Accumulation steps = 2
# [INFO|trainer.py:1768] 2023-10-03 10:23:40,423 >>   Total optimization steps = 13,158
# [INFO|trainer.py:1769] 2023-10-03 10:23:40,425 >>   Number of trainable parameters = 124,439,808
#     <div>
#
#       <progress value='13158' max='13158' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [13158/13158 2:35:21, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>1.677900</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>1.663900</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>1.672800</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>1.667900</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>1.674700</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>1.672900</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>1.668000</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>1.666500</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>1.665400</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>1.667600</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>1.657300</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>1.668900</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>1.660800</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>1.664000</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>1.662300</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>1.665100</td>
#     </tr>
#     <tr>
#       <td>8500</td>
#       <td>1.663900</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>1.659200</td>
#     </tr>
#     <tr>
#       <td>9500</td>
#       <td>1.668200</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>1.655400</td>
#     </tr>
#     <tr>
#       <td>10500</td>
#       <td>1.657900</td>
#     </tr>
#     <tr>
#       <td>11000</td>
#       <td>1.657000</td>
#     </tr>
#     <tr>
#       <td>11500</td>
#       <td>1.659100</td>
#     </tr>
#     <tr>
#       <td>12000</td>
#       <td>1.670100</td>
#     </tr>
#     <tr>
#       <td>12500</td>
#       <td>1.658300</td>
#     </tr>
#     <tr>
#       <td>13000</td>
#       <td>1.647500</td>
#     </tr>
#   </tbody>
# </table><p>
# [INFO|trainer.py:2939] 2023-10-03 10:29:37,998 >> Saving model checkpoint to model_tuned4/checkpoint-500
# [INFO|configuration_utils.py:460] 2023-10-03 10:29:38,003 >> Configuration saved in model_tuned4/checkpoint-500/config.json
# [INFO|configuration_utils.py:544] 2023-10-03 10:29:38,009 >> Configuration saved in model_tuned4/checkpoint-500/generation_config.json
# [INFO|modeling_utils.py:2114] 2023-10-03 10:29:39,105 >> Model weights saved in model_tuned4/checkpoint-500/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2431] 2023-10-03 10:29:39,111 >> tokenizer config file saved in model_tuned4/checkpoint-500/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2440] 2023-10-03 10:29:39,115 >> Special tokens file saved in model_tuned4/checkpoint-500/special_tokens_map.json
# [INFO|trainer.py:2939] 2023-10-03 10:35:33,294 >> Saving model checkpoint to model_tuned4/checkpoint-1000
# [INFO|configuration_utils.py:460] 2023-10-03 10:35:33,299 >> Configuration saved in model_tuned4/checkpoint-1000/config.json
# [INFO|configuration_utils.py:544] 2023-10-03 10:35:33,303 >> Configuration saved in model_tuned4/checkpoint-1000/generation_config.json
# [INFO|modeling_utils.py:2114] 2023-10-03 10:35:34,421 >> Model weights saved in model_tuned4/checkpoint-1000/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2431] 2023-10-03 10:35:34,427 >> tokenizer config file saved in model_tuned4/checkpoint-1000/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2440] 2023-10-03 10:35:34,431 >> Special tokens file saved in model_tuned4/checkpoint-1000/special_tokens_map.json
# [INFO|trainer.py:2939] 2023-10-03 10:41:26,829 >> Saving model checkpoint to model_tuned4/checkpoint-1500
# [INFO|configuration_utils.py:460] 2023-10-03 10:41:26,835 >> Configuration saved in model_tuned4/checkpoint-1500/config.json
# [INFO|configuration_utils.py:544] 2023-10-03 10:41:26,840 >> Configuration saved in model_tuned4/checkpoint-1500/generation_config.json
# [INFO|modeling_utils.py:2114] 2023-10-03 10:41:27,918 >> Model weights saved in model_tuned4/checkpoint-1500/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2431] 2023-10-03 10:41:27,923 >> tokenizer config file saved in model_tuned4/checkpoint-1500/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2440] 2023-10-03 10:41:27,927 >> Special tokens file saved in model_tuned4/checkpoint-1500/special_tokens_map.json
# [INFO|trainer.py:3026] 2023-10-03 10:41:30,423 >> Deleting older checkpoint [model_tuned4/checkpoint-500] due to args.save_total_limit
# [INFO|trainer.py:2939] 2023-10-03 10:47:22,869 >> Saving model checkpoint to model_tuned4/checkpoint-2000
# [INFO|configuration_utils.py:460] 2023-10-03 10:47:22,875 >> Configuration saved in model_tuned4/checkpoint-2000/config.json
# [INFO|configuration_utils.py:544] 2023-10-03 10:47:22,880 >> Configuration saved in model_tuned4/checkpoint-2000/generation_config.json
# [INFO|modeling_utils.py:2114] 2023-10-03 10:47:23,988 >> Model weights saved in model_tuned4/checkpoint-2000/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2431] 2023-10-03 10:47:23,994 >> tokenizer config file saved in model_tuned4/checkpoint-2000/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2440] 2023-10-03 10:47:23,998 >> Special tokens file saved in model_tuned4/checkpoint-2000/special_tokens_map.json
# [INFO|trainer.py:3026] 2023-10-03 10:47:26,562 >> Deleting older checkpoint [model_tuned4/checkpoint-1000] due to args.save_total_limit
# [INFO|trainer.py:2939] 2023-10-03 10:53:18,055 >> Saving model checkpoint to model_tuned4/checkpoint-2500
# [INFO|configuration_utils.py:460] 2023-10-03 10:53:18,060 >> Configuration saved in model_tuned4/checkpoint-2500/config.json
# [INFO|configuration_utils.py:544] 2023-10-03 10:53:18,065 >> Configuration saved in model_tuned4/checkpoint-2500/generation_config.json
# [INFO|modeling_utils.py:2114] 2023-10-03 10:53:19,157 >> Model weights saved in model_tuned4/checkpoint-2500/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2431] 2023-10-03 10:53:19,162 >> tokenizer config file saved in model_tuned4/checkpoint-2500/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2440] 2023-10-03 10:53:19,167 >> Special tokens file saved in model_tuned4/checkpoint-2500/special_tokens_map.json
# [INFO|trainer.py:3026] 2023-10-03 10:53:21,486 >> Deleting older checkpoint [model_tuned4/checkpoint-1500] due to args.save_total_limit
# [INFO|trainer.py:2939] 2023-10-03 10:59:12,365 >> Saving model checkpoint to model_tuned4/checkpoint-3000
# [INFO|configuration_utils.py:460] 2023-10-03 10:59:12,371 >> Configuration saved in model_tuned4/checkpoint-3000/config.json
# [INFO|configuration_utils.py:544] 2023-10-03 10:59:12,376 >> Configuration saved in model_tuned4/checkpoint-3000/generation_config.json
# [INFO|modeling_utils.py:2114] 2023-10-03 10:59:13,462 >> Model weights saved in model_tuned4/checkpoint-3000/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2431] 2023-10-03 10:59:13,467 >> tokenizer config file saved in model_tuned4/checkpoint-3000/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2440] 2023-10-03 10:59:13,471 >> Special tokens file saved in model_tuned4/checkpoint-3000/special_tokens_map.json
# [INFO|trainer.py:3026] 2023-10-03 10:59:16,007 >> Deleting older checkpoint [model_tuned4/checkpoint-2000] due to args.save_total_limit
# [INFO|trainer.py:2939] 2023-10-03 11:05:08,399 >> Saving model checkpoint to model_tuned4/checkpoint-3500
# [INFO|configuration_utils.py:460] 2023-10-03 11:05:08,405 >> Configuration saved in model_tuned4/checkpoint-3500/config.json
# [INFO|configuration_utils.py:544] 2023-10-03 11:05:08,409 >> Configuration saved in model_tuned4/checkpoint-3500/generation_config.json
# [INFO|modeling_utils.py:2114] 2023-10-03 11:05:09,483 >> Model weights saved in model_tuned4/checkpoint-3500/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2431] 2023-10-03 11:05:09,488 >> tokenizer config file saved in model_tuned4/checkpoint-3500/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2440] 2023-10-03 11:05:09,492 >> Special tokens file saved in model_tuned4/checkpoint-3500/special_tokens_map.json
# [INFO|trainer.py:3026] 2023-10-03 11:05:11,830 >> Deleting older checkpoint [model_tuned4/checkpoint-2500] due to args.save_total_limit
# [INFO|trainer.py:2939] 2023-10-03 11:11:01,715 >> Saving model checkpoint to model_tuned4/checkpoint-4000
# [INFO|configuration_utils.py:460] 2023-10-03 11:11:01,721 >> Configuration saved in model_tuned4/checkpoint-4000/config.json
# [INFO|configuration_utils.py:544] 2023-10-03 11:11:01,726 >> Configuration saved in model_tuned4/checkpoint-4000/generation_config.json
# [INFO|modeling_utils.py:2114] 2023-10-03 11:11:02,809 >> Model weights saved in model_tuned4/checkpoint-4000/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2431] 2023-10-03 11:11:02,814 >> tokenizer config file saved in model_tuned4/checkpoint-4000/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2440] 2023-10-03 11:11:02,818 >> Special tokens file saved in model_tuned4/checkpoint-4000/special_tokens_map.json
# [INFO|trainer.py:3026] 2023-10-03 11:11:05,357 >> Deleting older checkpoint [model_tuned4/checkpoint-3000] due to args.save_total_limit
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 120 worker processes in total. Our suggested max number of worker in current system is 12, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# [INFO|trainer.py:2939] 2023-10-03 11:17:03,104 >> Saving model checkpoint to model_tuned4/checkpoint-4500
# [INFO|configuration_utils.py:460] 2023-10-03 11:17:03,111 >> Configuration saved in model_tuned4/checkpoint-4500/config.json
# [INFO|configuration_utils.py:544] 2023-10-03 11:17:03,115 >> Configuration saved in model_tuned4/checkpoint-4500/generation_config.json
# [INFO|modeling_utils.py:2114] 2023-10-03 11:17:04,228 >> Model weights saved in model_tuned4/checkpoint-4500/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2431] 2023-10-03 11:17:04,235 >> tokenizer config file saved in model_tuned4/checkpoint-4500/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2440] 2023-10-03 11:17:04,240 >> Special tokens file saved in model_tuned4/checkpoint-4500/special_tokens_map.json
# [INFO|trainer.py:3026] 2023-10-03 11:17:10,421 >> Deleting older checkpoint [model_tuned4/checkpoint-3500] due to args.save_total_limit
# [INFO|trainer.py:2939] 2023-10-03 11:22:58,797 >> Saving model checkpoint to model_tuned4/checkpoint-5000
# [INFO|configuration_utils.py:460] 2023-10-03 11:22:58,803 >> Configuration saved in model_tuned4/checkpoint-5000/config.json
# [INFO|configuration_utils.py:544] 2023-10-03 11:22:58,819 >> Configuration saved in model_tuned4/checkpoint-5000/generation_config.json
# [INFO|modeling_utils.py:2114] 2023-10-03 11:22:59,952 >> Model weights saved in model_tuned4/checkpoint-5000/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2431] 2023-10-03 11:22:59,957 >> tokenizer config file saved in model_tuned4/checkpoint-5000/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2440] 2023-10-03 11:22:59,961 >> Special tokens file saved in model_tuned4/checkpoint-5000/special_tokens_map.json
# [INFO|trainer.py:3026] 2023-10-03 11:23:02,532 >> Deleting older checkpoint [model_tuned4/checkpoint-4000] due to args.save_total_limit
# [INFO|trainer.py:2939] 2023-10-03 11:28:50,708 >> Saving model checkpoint to model_tuned4/checkpoint-5500
# [INFO|configuration_utils.py:460] 2023-10-03 11:28:50,714 >> Configuration saved in model_tuned4/checkpoint-5500/config.json
# [INFO|configuration_utils.py:544] 2023-10-03 11:28:50,718 >> Configuration saved in model_tuned4/checkpoint-5500/generation_config.json
# [INFO|modeling_utils.py:2114] 2023-10-03 11:28:51,803 >> Model weights saved in model_tuned4/checkpoint-5500/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2431] 2023-10-03 11:28:51,808 >> tokenizer config file saved in model_tuned4/checkpoint-5500/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2440] 2023-10-03 11:28:51,812 >> Special tokens file saved in model_tuned4/checkpoint-5500/special_tokens_map.json
# [INFO|trainer.py:3026] 2023-10-03 11:28:54,241 >> Deleting older checkpoint [model_tuned4/checkpoint-4500] due to args.save_total_limit
# [INFO|trainer.py:2939] 2023-10-03 11:34:42,561 >> Saving model checkpoint to model_tuned4/checkpoint-6000
# [INFO|configuration_utils.py:460] 2023-10-03 11:34:42,566 >> Configuration saved in model_tuned4/checkpoint-6000/config.json
# [INFO|configuration_utils.py:544] 2023-10-03 11:34:42,571 >> Configuration saved in model_tuned4/checkpoint-6000/generation_config.json
# [INFO|modeling_utils.py:2114] 2023-10-03 11:34:43,704 >> Model weights saved in model_tuned4/checkpoint-6000/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2431] 2023-10-03 11:34:43,709 >> tokenizer config file saved in model_tuned4/checkpoint-6000/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2440] 2023-10-03 11:34:43,713 >> Special tokens file saved in model_tuned4/checkpoint-6000/special_tokens_map.json
# [INFO|trainer.py:3026] 2023-10-03 11:34:46,294 >> Deleting older checkpoint [model_tuned4/checkpoint-5000] due to args.save_total_limit
# [INFO|trainer.py:2939] 2023-10-03 11:40:38,023 >> Saving model checkpoint to model_tuned4/checkpoint-6500
# [INFO|configuration_utils.py:460] 2023-10-03 11:40:38,028 >> Configuration saved in model_tuned4/checkpoint-6500/config.json
# [INFO|configuration_utils.py:544] 2023-10-03 11:40:38,033 >> Configuration saved in model_tuned4/checkpoint-6500/generation_config.json
# [INFO|modeling_utils.py:2114] 2023-10-03 11:40:39,162 >> Model weights saved in model_tuned4/checkpoint-6500/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2431] 2023-10-03 11:40:39,168 >> tokenizer config file saved in model_tuned4/checkpoint-6500/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2440] 2023-10-03 11:40:39,171 >> Special tokens file saved in model_tuned4/checkpoint-6500/special_tokens_map.json
# [INFO|trainer.py:3026] 2023-10-03 11:40:41,681 >> Deleting older checkpoint [model_tuned4/checkpoint-5500] due to args.save_total_limit
# [INFO|trainer.py:2939] 2023-10-03 11:46:34,420 >> Saving model checkpoint to model_tuned4/checkpoint-7000
# [INFO|configuration_utils.py:460] 2023-10-03 11:46:34,427 >> Configuration saved in model_tuned4/checkpoint-7000/config.json
# [INFO|configuration_utils.py:544] 2023-10-03 11:46:34,432 >> Configuration saved in model_tuned4/checkpoint-7000/generation_config.json
# [INFO|modeling_utils.py:2114] 2023-10-03 11:46:35,553 >> Model weights saved in model_tuned4/checkpoint-7000/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2431] 2023-10-03 11:46:35,558 >> tokenizer config file saved in model_tuned4/checkpoint-7000/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2440] 2023-10-03 11:46:35,562 >> Special tokens file saved in model_tuned4/checkpoint-7000/special_tokens_map.json
# [INFO|trainer.py:3026] 2023-10-03 11:46:42,488 >> Deleting older checkpoint [model_tuned4/checkpoint-6000] due to args.save_total_limit
# [INFO|trainer.py:2939] 2023-10-03 11:52:30,599 >> Saving model checkpoint to model_tuned4/checkpoint-7500
# [INFO|configuration_utils.py:460] 2023-10-03 11:52:30,605 >> Configuration saved in model_tuned4/checkpoint-7500/config.json
# [INFO|configuration_utils.py:544] 2023-10-03 11:52:30,610 >> Configuration saved in model_tuned4/checkpoint-7500/generation_config.json
# [INFO|modeling_utils.py:2114] 2023-10-03 11:52:31,730 >> Model weights saved in model_tuned4/checkpoint-7500/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2431] 2023-10-03 11:52:31,735 >> tokenizer config file saved in model_tuned4/checkpoint-7500/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2440] 2023-10-03 11:52:31,740 >> Special tokens file saved in model_tuned4/checkpoint-7500/special_tokens_map.json
# [INFO|trainer.py:3026] 2023-10-03 11:52:34,381 >> Deleting older checkpoint [model_tuned4/checkpoint-6500] due to args.save_total_limit
# [INFO|trainer.py:2939] 2023-10-03 11:58:22,464 >> Saving model checkpoint to model_tuned4/checkpoint-8000
# [INFO|configuration_utils.py:460] 2023-10-03 11:58:22,470 >> Configuration saved in model_tuned4/checkpoint-8000/config.json
# [INFO|configuration_utils.py:544] 2023-10-03 11:58:22,474 >> Configuration saved in model_tuned4/checkpoint-8000/generation_config.json
# [INFO|modeling_utils.py:2114] 2023-10-03 11:58:23,579 >> Model weights saved in model_tuned4/checkpoint-8000/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2431] 2023-10-03 11:58:23,585 >> tokenizer config file saved in model_tuned4/checkpoint-8000/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2440] 2023-10-03 11:58:23,589 >> Special tokens file saved in model_tuned4/checkpoint-8000/special_tokens_map.json
# [INFO|trainer.py:3026] 2023-10-03 11:58:26,165 >> Deleting older checkpoint [model_tuned4/checkpoint-7000] due to args.save_total_limit
# [INFO|trainer.py:2939] 2023-10-03 12:04:14,332 >> Saving model checkpoint to model_tuned4/checkpoint-8500
# [INFO|configuration_utils.py:460] 2023-10-03 12:04:14,338 >> Configuration saved in model_tuned4/checkpoint-8500/config.json
# [INFO|configuration_utils.py:544] 2023-10-03 12:04:14,343 >> Configuration saved in model_tuned4/checkpoint-8500/generation_config.json
# [INFO|modeling_utils.py:2114] 2023-10-03 12:04:15,471 >> Model weights saved in model_tuned4/checkpoint-8500/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2431] 2023-10-03 12:04:15,477 >> tokenizer config file saved in model_tuned4/checkpoint-8500/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2440] 2023-10-03 12:04:15,480 >> Special tokens file saved in model_tuned4/checkpoint-8500/special_tokens_map.json
# [INFO|trainer.py:3026] 2023-10-03 12:04:18,047 >> Deleting older checkpoint [model_tuned4/checkpoint-7500] due to args.save_total_limit
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 120 worker processes in total. Our suggested max number of worker in current system is 12, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# [INFO|trainer.py:2939] 2023-10-03 12:10:12,037 >> Saving model checkpoint to model_tuned4/checkpoint-9000
# [INFO|configuration_utils.py:460] 2023-10-03 12:10:12,044 >> Configuration saved in model_tuned4/checkpoint-9000/config.json
# [INFO|configuration_utils.py:544] 2023-10-03 12:10:12,060 >> Configuration saved in model_tuned4/checkpoint-9000/generation_config.json
# [INFO|modeling_utils.py:2114] 2023-10-03 12:10:13,164 >> Model weights saved in model_tuned4/checkpoint-9000/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2431] 2023-10-03 12:10:13,172 >> tokenizer config file saved in model_tuned4/checkpoint-9000/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2440] 2023-10-03 12:10:13,175 >> Special tokens file saved in model_tuned4/checkpoint-9000/special_tokens_map.json
# [INFO|trainer.py:3026] 2023-10-03 12:10:15,712 >> Deleting older checkpoint [model_tuned4/checkpoint-8000] due to args.save_total_limit
# [INFO|trainer.py:2939] 2023-10-03 12:16:03,941 >> Saving model checkpoint to model_tuned4/checkpoint-9500
# [INFO|configuration_utils.py:460] 2023-10-03 12:16:03,947 >> Configuration saved in model_tuned4/checkpoint-9500/config.json
# [INFO|configuration_utils.py:544] 2023-10-03 12:16:03,952 >> Configuration saved in model_tuned4/checkpoint-9500/generation_config.json
# [INFO|modeling_utils.py:2114] 2023-10-03 12:16:05,120 >> Model weights saved in model_tuned4/checkpoint-9500/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2431] 2023-10-03 12:16:05,125 >> tokenizer config file saved in model_tuned4/checkpoint-9500/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2440] 2023-10-03 12:16:05,130 >> Special tokens file saved in model_tuned4/checkpoint-9500/special_tokens_map.json
# [INFO|trainer.py:3026] 2023-10-03 12:16:07,895 >> Deleting older checkpoint [model_tuned4/checkpoint-8500] due to args.save_total_limit
# [INFO|trainer.py:2939] 2023-10-03 12:21:56,143 >> Saving model checkpoint to model_tuned4/checkpoint-10000
# [INFO|configuration_utils.py:460] 2023-10-03 12:21:56,149 >> Configuration saved in model_tuned4/checkpoint-10000/config.json
# [INFO|configuration_utils.py:544] 2023-10-03 12:21:56,153 >> Configuration saved in model_tuned4/checkpoint-10000/generation_config.json
# [INFO|modeling_utils.py:2114] 2023-10-03 12:21:57,270 >> Model weights saved in model_tuned4/checkpoint-10000/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2431] 2023-10-03 12:21:57,277 >> tokenizer config file saved in model_tuned4/checkpoint-10000/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2440] 2023-10-03 12:21:57,281 >> Special tokens file saved in model_tuned4/checkpoint-10000/special_tokens_map.json
# [INFO|trainer.py:3026] 2023-10-03 12:21:59,775 >> Deleting older checkpoint [model_tuned4/checkpoint-9000] due to args.save_total_limit
# [INFO|trainer.py:2939] 2023-10-03 12:27:51,533 >> Saving model checkpoint to model_tuned4/checkpoint-10500
# [INFO|configuration_utils.py:460] 2023-10-03 12:27:51,540 >> Configuration saved in model_tuned4/checkpoint-10500/config.json
# [INFO|configuration_utils.py:544] 2023-10-03 12:27:51,544 >> Configuration saved in model_tuned4/checkpoint-10500/generation_config.json
# [INFO|modeling_utils.py:2114] 2023-10-03 12:27:52,652 >> Model weights saved in model_tuned4/checkpoint-10500/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2431] 2023-10-03 12:27:52,658 >> tokenizer config file saved in model_tuned4/checkpoint-10500/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2440] 2023-10-03 12:27:52,662 >> Special tokens file saved in model_tuned4/checkpoint-10500/special_tokens_map.json
# [INFO|trainer.py:3026] 2023-10-03 12:27:55,141 >> Deleting older checkpoint [model_tuned4/checkpoint-9500] due to args.save_total_limit
# [INFO|trainer.py:2939] 2023-10-03 12:33:47,694 >> Saving model checkpoint to model_tuned4/checkpoint-11000
# [INFO|configuration_utils.py:460] 2023-10-03 12:33:47,700 >> Configuration saved in model_tuned4/checkpoint-11000/config.json
# [INFO|configuration_utils.py:544] 2023-10-03 12:33:47,705 >> Configuration saved in model_tuned4/checkpoint-11000/generation_config.json
# [INFO|modeling_utils.py:2114] 2023-10-03 12:33:48,847 >> Model weights saved in model_tuned4/checkpoint-11000/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2431] 2023-10-03 12:33:48,853 >> tokenizer config file saved in model_tuned4/checkpoint-11000/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2440] 2023-10-03 12:33:48,857 >> Special tokens file saved in model_tuned4/checkpoint-11000/special_tokens_map.json
# [INFO|trainer.py:3026] 2023-10-03 12:33:54,463 >> Deleting older checkpoint [model_tuned4/checkpoint-10000] due to args.save_total_limit
# [INFO|trainer.py:2939] 2023-10-03 12:39:42,544 >> Saving model checkpoint to model_tuned4/checkpoint-11500
# [INFO|configuration_utils.py:460] 2023-10-03 12:39:42,549 >> Configuration saved in model_tuned4/checkpoint-11500/config.json
# [INFO|configuration_utils.py:544] 2023-10-03 12:39:42,554 >> Configuration saved in model_tuned4/checkpoint-11500/generation_config.json
# [INFO|modeling_utils.py:2114] 2023-10-03 12:39:43,632 >> Model weights saved in model_tuned4/checkpoint-11500/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2431] 2023-10-03 12:39:43,637 >> tokenizer config file saved in model_tuned4/checkpoint-11500/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2440] 2023-10-03 12:39:43,641 >> Special tokens file saved in model_tuned4/checkpoint-11500/special_tokens_map.json
# [INFO|trainer.py:3026] 2023-10-03 12:39:46,113 >> Deleting older checkpoint [model_tuned4/checkpoint-10500] due to args.save_total_limit
# [INFO|trainer.py:2939] 2023-10-03 12:45:34,290 >> Saving model checkpoint to model_tuned4/checkpoint-12000
# [INFO|configuration_utils.py:460] 2023-10-03 12:45:34,296 >> Configuration saved in model_tuned4/checkpoint-12000/config.json
# [INFO|configuration_utils.py:544] 2023-10-03 12:45:34,301 >> Configuration saved in model_tuned4/checkpoint-12000/generation_config.json
# [INFO|modeling_utils.py:2114] 2023-10-03 12:45:35,395 >> Model weights saved in model_tuned4/checkpoint-12000/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2431] 2023-10-03 12:45:35,401 >> tokenizer config file saved in model_tuned4/checkpoint-12000/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2440] 2023-10-03 12:45:35,406 >> Special tokens file saved in model_tuned4/checkpoint-12000/special_tokens_map.json
# [INFO|trainer.py:3026] 2023-10-03 12:45:37,976 >> Deleting older checkpoint [model_tuned4/checkpoint-11000] due to args.save_total_limit
# [INFO|trainer.py:2939] 2023-10-03 12:51:26,184 >> Saving model checkpoint to model_tuned4/checkpoint-12500
# [INFO|configuration_utils.py:460] 2023-10-03 12:51:26,190 >> Configuration saved in model_tuned4/checkpoint-12500/config.json
# [INFO|configuration_utils.py:544] 2023-10-03 12:51:26,209 >> Configuration saved in model_tuned4/checkpoint-12500/generation_config.json
# [INFO|modeling_utils.py:2114] 2023-10-03 12:51:27,342 >> Model weights saved in model_tuned4/checkpoint-12500/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2431] 2023-10-03 12:51:27,348 >> tokenizer config file saved in model_tuned4/checkpoint-12500/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2440] 2023-10-03 12:51:27,352 >> Special tokens file saved in model_tuned4/checkpoint-12500/special_tokens_map.json
# [INFO|trainer.py:3026] 2023-10-03 12:51:29,921 >> Deleting older checkpoint [model_tuned4/checkpoint-11500] due to args.save_total_limit
# [INFO|trainer.py:2939] 2023-10-03 12:57:18,038 >> Saving model checkpoint to model_tuned4/checkpoint-13000
# [INFO|configuration_utils.py:460] 2023-10-03 12:57:18,043 >> Configuration saved in model_tuned4/checkpoint-13000/config.json
# [INFO|configuration_utils.py:544] 2023-10-03 12:57:18,048 >> Configuration saved in model_tuned4/checkpoint-13000/generation_config.json
# [INFO|modeling_utils.py:2114] 2023-10-03 12:57:19,145 >> Model weights saved in model_tuned4/checkpoint-13000/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2431] 2023-10-03 12:57:19,152 >> tokenizer config file saved in model_tuned4/checkpoint-13000/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2440] 2023-10-03 12:57:19,156 >> Special tokens file saved in model_tuned4/checkpoint-13000/special_tokens_map.json
# [INFO|trainer.py:3026] 2023-10-03 12:57:21,679 >> Deleting older checkpoint [model_tuned4/checkpoint-12000] due to args.save_total_limit
# [INFO|trainer.py:2017] 2023-10-03 12:59:12,144 >>
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# [INFO|trainer.py:2939] 2023-10-03 12:59:12,151 >> Saving model checkpoint to model_tuned4
# [INFO|configuration_utils.py:460] 2023-10-03 12:59:12,157 >> Configuration saved in model_tuned4/config.json
# [INFO|configuration_utils.py:544] 2023-10-03 12:59:12,161 >> Configuration saved in model_tuned4/generation_config.json
# [INFO|modeling_utils.py:2114] 2023-10-03 12:59:13,289 >> Model weights saved in model_tuned4/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2431] 2023-10-03 12:59:13,297 >> tokenizer config file saved in model_tuned4/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2440] 2023-10-03 12:59:13,301 >> Special tokens file saved in model_tuned4/special_tokens_map.json
# INFO:__main__:*** Evaluate ***
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 120 worker processes in total. Our suggested max number of worker in current system is 12, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# [INFO|trainer.py:3213] 2023-10-03 12:59:13,434 >> ***** Running Evaluation *****
# [INFO|trainer.py:3215] 2023-10-03 12:59:13,435 >>   Num examples = 4285
# [INFO|trainer.py:3218] 2023-10-03 12:59:13,436 >>   Batch size = 8
# ***** train metrics *****
#   epoch                    =         3.0
#   total_flos               = 153679576GF
#   train_loss               =      1.6643
#   train_runtime            =  2:35:31.71
#   train_samples            =      105254
#   train_samples_per_second =      33.837
#   train_steps_per_second   =        1.41
#     <div>
#
#       <progress value='536' max='536' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [536/536 00:48]
#     </div>
# ***** eval metrics *****
#   epoch                   =        3.0
#   eval_accuracy           =     0.6565
#   eval_loss               =     1.6914
#   eval_runtime            = 0:01:14.93
#   eval_samples            =       4285
#   eval_samples_per_second =     57.182
#   eval_steps_per_second   =      7.153
#   perplexity              =     5.4271
# [INFO|modelcard.py:452] 2023-10-03 13:00:28,752 >> Dropping the following result as it does not have all the necessary fields:
# {'task': {'name': 'Causal Language Modeling', 'type': 'text-generation'}, 'metrics': [{'name': 'Accuracy', 'type': 'accuracy', 'value': 0.6565488513318528}]}
